# %%
import json
import re 
from pathlib import Path
from owlready2 import *
import os

# %%
BASE_DIR = Path(os.getcwd())
ONTOLOGY_PATH = BASE_DIR / "german_city_tourism_final_d2.owl"
OUTPUT_PATH = BASE_DIR / "german_city_tourism_with_rules.owl"

# %%
onto = get_ontology(str(ONTOLOGY_PATH)).load()

# %%
sync_reasoner_hermit()
# Out:
# * Owlready2 * Running HermiT...
#     java -Xmx2000M -cp /Users/conocirone/Library/Python/3.9/lib/python/site-packages/owlready2/hermit:/Users/conocirone/Library/Python/3.9/lib/python/site-packages/owlready2/hermit/HermiT.jar org.semanticweb.HermiT.cli.CommandLine -c -O -D -I file:////var/folders/rw/1_0ppc711wv8ynhlpz9d75mm0000gn/T/tmpftziidu1
# * Owlready2 * HermiT took 1.2818348407745361 seconds
# * Owlready * Equivalenting: owl.Thing DUL.Entity
# * Owlready * Equivalenting: DUL.Entity owl.Thing
# * Owlready * Reparenting DUL.hasTask: {owl.ObjectProperty, DUL.isRelatedToConcept} => {DUL.isRelatedToConcept}
# * Owlready * Reparenting DUL.isSubordinatedTo: {owl.ObjectProperty, DUL.isRelatedToConcept, DUL.directlyFollows} => {DUL.isRelatedToConcept, DUL.directlyFollows}
# * Owlready * Reparenting DUL.isTaskOf: {owl.ObjectProperty, DUL.isRelatedToConcept} => {DUL.isRelatedToConcept}
# ...

# %%
# Tour(?t) ^ hasLanguage(?t, lang_english) -> EnglishFriendlyTour(?t)
# Activity(?a) ^ hasLocationSetting(?a, location_indoor) -> RainyDayOption(?a)
# Activity(?a) ^ hasLocationSetting(?a, location_outdoor) -> SunnyDayOption(?a)
# Park(?p) -> FamilyFriendlyActivity(?p)
# NightlifeVenue(?n) -> EveningActivity(?n)

# %%
onto.save(file=OUTPUT_PATH, format="rdfxml")
