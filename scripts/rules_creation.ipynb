# %% [markdown]
# # SWRL Rules Creation
#
# This notebook implements 5 SWRL rules that infer new class memberships based on existing properties:
#
# 1. **BudgetFriendlyActivity**: Activities with `budget_free` or `budget_low`
# 2. **BadWeatherOption**: Activities with `location_indoor` setting
# 3. **EnglishFriendlyTour**: Tours available in English
# 4. **WeekendHours**: Operating hours that apply to Saturday or Sunday
# 5. **OpenOnWeekend**: Physical venues with weekend operating hours

# %%
from pathlib import Path
from owlready2 import *
import os

# %%
# Define paths
BASE_DIR = Path(os.getcwd()).parent
ONTOLOGY_PATH = BASE_DIR / "ontologies" / "populated" / "german_city_tourism_populated.owl"
OUTPUT_PATH = BASE_DIR / "ontologies" / "populated" / "german_city_tourism_with_rules.owl"

print(f"Loading ontology from: {ONTOLOGY_PATH}")
# Out:
# Loading ontology from: /Users/conocirone/Desktop/german_travel_companion/ontologies/populated/german_city_tourism_populated.owl

# %%
# Load the ontology
onto = get_ontology(str(ONTOLOGY_PATH)).load()

# %%
with onto:
    class BudgetFriendlyActivity(onto.Activity):
        """An activity that is free or low-cost, suitable for budget-conscious travelers."""
        pass
    
    class BadWeatherOption(onto.Activity):
        """An indoor activity suitable for rainy or bad weather days."""
        pass
    
    class EnglishFriendlyTour(onto.Tour):
        """A tour that is available in English, accessible for international tourists."""
        pass
    
    class WeekendHours(onto.OperatingHours):
        """Operating hours that apply to weekend days."""
        pass
    
    class OpenOnWeekend(onto.PhysicalVenue):
        """A physical venue that is open on weekends."""
        pass

# %%
budget_free = onto.budget_free
budget_low = onto.budget_low
location_indoor = onto.location_indoor
lang_english = onto.lang_english
day_saturday = onto.day_saturday  
day_sunday = onto.day_sunday     

print("Retrieved instances:")
print(f"  - budget_free: {budget_free}")
print(f"  - budget_low: {budget_low}")
print(f"  - location_indoor: {location_indoor}")
print(f"  - lang_english: {lang_english}")
print(f"  - day_saturday: {day_saturday}") 
print(f"  - day_sunday: {day_sunday}")
# Out:
# Retrieved instances:
#   - budget_free: german_city_tourism_populated.budget_free
#   - budget_low: german_city_tourism_populated.budget_low
#   - location_indoor: german_city_tourism_populated.location_indoor
#   - lang_english: german_city_tourism_populated.lang_english
#   - day_saturday: german_city_tourism_populated.day_saturday
#   - day_sunday: german_city_tourism_populated.day_sunday

# %%
# Define SWRL rules using Owlready2's Imp (implies) class
with onto:
    # Rule 1a: Activity(?a) ^ hasBudget(?a, budget_free) -> BudgetFriendlyActivity(?a)
    rule1a = Imp()
    rule1a.set_as_rule(
        "Activity(?a), hasBudget(?a, budget_free) -> BudgetFriendlyActivity(?a)"
    )
    
    # Rule 1b: Activity(?a) ^ hasBudget(?a, budget_low) -> BudgetFriendlyActivity(?a)
    rule1b = Imp()
    rule1b.set_as_rule(
        "Activity(?a), hasBudget(?a, budget_low) -> BudgetFriendlyActivity(?a)"
    )
    
    # Rule 2: Activity(?a) ^ hasLocationSetting(?a, location_indoor) -> BadWeatherOption(?a)
    rule2 = Imp()
    rule2.set_as_rule(
        "Activity(?a), hasLocationSetting(?a, location_indoor) -> BadWeatherOption(?a)"
    )
    
    # Rule 3: Tour(?t) ^ hasLanguage(?t, lang_english) -> EnglishFriendlyTour(?t)
    rule3 = Imp()
    rule3.set_as_rule(
        "Tour(?t), hasLanguage(?t, lang_english) -> EnglishFriendlyTour(?t)"
    )
    
    # Rule 5a: Saturday hours -> WeekendHours
    rule5a = Imp()
    rule5a.set_as_rule(
        "OperatingHours(?oh), appliesToDay(?oh, day_saturday) -> WeekendHours(?oh)"
    )
    
    # Rule 5b: Sunday hours -> WeekendHours
    rule5b = Imp()
    rule5b.set_as_rule(
        "OperatingHours(?oh), appliesToDay(?oh, day_sunday) -> WeekendHours(?oh)"
    )
    
    # Rule 6: Venue with weekend hours -> OpenOnWeekend
    rule6 = Imp()
    rule6.set_as_rule(
        "PhysicalVenue(?v), hasOperatingHours(?v, ?oh), WeekendHours(?oh) -> OpenOnWeekend(?v)"
    )

# %%
sync_reasoner_hermit(infer_property_values=True)
#sync_reasoner_pellet(infer_data_property_values=True, infer_property_values=True)
# Out:
# * Owlready2 * Running HermiT...
#     java -Xmx2000M -cp /Users/conocirone/Library/Python/3.9/lib/python/site-packages/owlready2/hermit:/Users/conocirone/Library/Python/3.9/lib/python/site-packages/owlready2/hermit/HermiT.jar org.semanticweb.HermiT.cli.CommandLine -c -O -D -I file:////var/folders/rw/1_0ppc711wv8ynhlpz9d75mm0000gn/T/tmp17sriiao -Y
# * Owlready2 * HermiT took 289.90364813804626 seconds
# * Owlready * Equivalenting: owl.Thing DUL.Entity
# * Owlready * Equivalenting: DUL.Entity owl.Thing
# * Owlready * Reparenting german_city_tourism_populated.DayOfWeek: {DUL.Concept, owl.Thing} => {DUL.Concept}
# * Owlready * Reparenting german_city_tourism_populated.OperatingHours: {DUL.TimeInterval, owl.Thing} => {DUL.TimeInterval}
# * Owlready * Reparenting DUL.parametrizes: {owl.ObjectProperty, DUL.classifies} => {DUL.classifies}
# * Owlready * Reparenting DUL.realizes: {owl.ObjectProperty, DUL.associatedWith} => {DUL.associatedWith}
# * Owlready * Reparenting DUL.hasRegion: {owl.ObjectProperty, DUL.associatedWith} => {DUL.associatedWith}
# * Owlready * Reparenting DUL.isSettingFor: {owl.ObjectProperty, DUL.associatedWith} => {DUL.associatedWith}
# * Owlready * Reparenting DUL.realizesInformationAbout: {owl.ObjectProperty, DUL.associatedWith} => {DUL.associatedWith}
# * Owlready * Reparenting DUL.classifies: {owl.ObjectProperty, DUL.associatedWith} => {DUL.associatedWith}
# * Owlready * Reparenting DUL.isConcretelyExpressedBy: {owl.ObjectProperty, DUL.associatedWith} => {DUL.associatedWith}
# * Owlready * Reparenting DUL.hasLocation: {owl.ObjectProperty, DUL.associatedWith} => {DUL.associatedWith}
# * Owlready * Reparenting DUL.isPreconditionOf: {owl.ObjectProperty, DUL.directlyPrecedes} => {DUL.directlyPrecedes}
# * Owlready * Reparenting DUL.includesObject: {DUL.isSettingFor, owl.ObjectProperty} => {DUL.isSettingFor}
# * Owlready * Reparenting DUL.includesTime: {DUL.isSettingFor, owl.ObjectProperty} => {DUL.isSettingFor}
# * Owlready * Reparenting german_city_tourism_populated.venue_quatsch_comedy_club_hamburg_828: {german_city_tourism_populated.NightlifeVenue, german_city_tourism_populated.RainyDayOption} => {german_city_tourism_populated.RainyDayOption, german_city_tourism_populated.NightlifeVenue, german_city_tourism_populated.BadWeatherOption}
# * Owlready * Reparenting german_city_tourism_populated.venue_bar_rix_404: {german_city_tourism_populated.BudgetFriendlyActivity, german_city_tourism_populated.NightlifeVenue, german_city_tourism_populated.RainyDayOption} => {german_city_tourism_populated.BudgetFriendlyActivity, german_city_tourism_populated.RainyDayOption, german_city_tourism_populated.NightlifeVenue, german_city_tourism_populated.BadWeatherOption, german_city_tourism_populated.OpenOnWeekend}
# * Owlready * Reparenting german_city_tourism_populated.venue_museum_funf_kontinente_559: {german_city_tourism_populated.BudgetFriendlyActivity, german_city_tourism_populated.Museum, german_city_tourism_populated.RainyDayOption} => {german_city_tourism_populated.BudgetFriendlyActivity, german_city_tourism_populated.RainyDayOption, german_city_tourism_populated.Museum, german_city_tourism_populated.BadWeatherOption, german_city_tourism_populated.OpenOnWeekend}
# * Owlready * Reparenting german_city_tourism_populated.venue_deutsches_zollmuseum_793: {german_city_tourism_populated.BudgetFriendlyActivity, german_city_tourism_populated.Museum, german_city_tourism_populated.RainyDayOption} => {german_city_tourism_populated.BudgetFriendlyActivity, german_city_tourism_populated.RainyDayOption, german_city_tourism_populated.Museum, german_city_tourism_populated.BadWeatherOption, german_city_tourism_populated.OpenOnWeekend}
# * Owlready * Reparenting german_city_tourism_populated.venue_ecs_gruppe_gebäudereinigung_1611: {german_city_tourism_populated.BudgetFriendlyActivity, german_city_tourism_populated.Park, german_city_tourism_populated.FamilyFriendlyActivity} => {german_city_tourism_populated.BudgetFriendlyActivity, german_city_tourism_populated.FamilyFriendlyActivity, german_city_tourism_populated.Park, german_city_tourism_populated.OpenOnWeekend}
# * Owlready * Reparenting german_city_tourism_populated.venue_bunkermuseum_742: {german_city_tourism_populated.BudgetFriendlyActivity, german_city_tourism_populated.Sight, german_city_tourism_populated.RainyDayOption} => {german_city_tourism_populated.BudgetFriendlyActivity, german_city_tourism_populated.RainyDayOption, german_city_tourism_populated.Sight, german_city_tourism_populated.BadWeatherOption}
# * Owlready * Reparenting german_city_tourism_populated.venue_lucky_bar_stuttgart_wangen_1326: {german_city_tourism_populated.BudgetFriendlyActivity, german_city_tourism_populated.NightlifeVenue, german_city_tourism_populated.RainyDayOption} => {german_city_tourism_populated.BudgetFriendlyActivity, german_city_tourism_populated.RainyDayOption, german_city_tourism_populated.NightlifeVenue, german_city_tourism_populated.BadWeatherOption, german_city_tourism_populated.OpenOnWeekend}
# * Owlready * Reparenting german_city_tourism_populated.venue_kunsthaus_rhenania_316: {german_city_tourism_populated.BudgetFriendlyActivity, german_city_tourism_populated.Museum, german_city_tourism_populated.RainyDayOption} => {german_city_tourism_populated.BudgetFriendlyActivity, german_city_tourism_populated.RainyDayOption, german_city_tourism_populated.Museum, german_city_tourism_populated.BadWeatherOption}
# * Owlready * Reparenting german_city_tourism_populated.venue_dark_matter_84: {german_city_tourism_populated.Museum, german_city_tourism_populated.RainyDayOption} => {german_city_tourism_populated.RainyDayOption, german_city_tourism_populated.Museum, german_city_tourism_populated.BadWeatherOption, german_city_tourism_populated.OpenOnWeekend}
# * Owlready * Reparenting german_city_tourism_populated.venue_volksparkstadion_726: {german_city_tourism_populated.BudgetFriendlyActivity, german_city_tourism_populated.Sight} => {german_city_tourism_populated.BudgetFriendlyActivity, german_city_tourism_populated.Sight, german_city_tourism_populated.OpenOnWeekend}
# * Owlready * Reparenting german_city_tourism_populated.venue_art_for_life_tätowierungen_1696: {german_city_tourism_populated.BudgetFriendlyActivity, german_city_tourism_populated.Museum, german_city_tourism_populated.RainyDayOption} => {german_city_tourism_populated.BudgetFriendlyActivity, german_city_tourism_populated.RainyDayOption, german_city_tourism_populated.Museum, german_city_tourism_populated.BadWeatherOption}
# * Owlready * Reparenting german_city_tourism_populated.venue_basement_1861: {german_city_tourism_populated.BudgetFriendlyActivity, german_city_tourism_populated.Museum, german_city_tourism_populated.RainyDayOption} => {german_city_tourism_populated.BudgetFriendlyActivity, german_city_tourism_populated.RainyDayOption, german_city_tourism_populated.Museum, german_city_tourism_populated.BadWeatherOption}
# * Owlready * Reparenting german_city_tourism_populated.venue_theodor_heuss_haus_1241: {german_city_tourism_populated.BudgetFriendlyActivity, german_city_tourism_populated.Museum, german_city_tourism_populated.RainyDayOption} => {german_city_tourism_populated.BudgetFriendlyActivity, german_city_tourism_populated.RainyDayOption, german_city_tourism_populated.Museum, german_city_tourism_populated.BadWeatherOption, german_city_tourism_populated.OpenOnWeekend}
# * Owlready * Reparenting german_city_tourism_populated.venue_bananas_shisha_lounge_1083: {german_city_tourism_populated.BudgetFriendlyActivity, german_city_tourism_populated.NightlifeVenue, german_city_tourism_populated.RainyDayOption} => {german_city_tourism_populated.BudgetFriendlyActivity, german_city_tourism_populated.RainyDayOption, german_city_tourism_populated.NightlifeVenue, german_city_tourism_populated.BadWeatherOption}
# * Owlready * Reparenting german_city_tourism_populated.venue_deutsches_theatermuseum_584: {german_city_tourism_populated.BudgetFriendlyActivity, german_city_tourism_populated.Museum, german_city_tourism_populated.RainyDayOption} => {german_city_tourism_populated.BudgetFriendlyActivity, german_city_tourism_populated.RainyDayOption, german_city_tourism_populated.Museum, german_city_tourism_populated.BadWeatherOption}
# * Owlready * Reparenting german_city_tourism_populated.venue_museum_angewandte_kunst_1035: {german_city_tourism_populated.BudgetFriendlyActivity, german_city_tourism_populated.Museum, german_city_tourism_populated.RainyDayOption} => {german_city_tourism_populated.BudgetFriendlyActivity, german_city_tourism_populated.RainyDayOption, german_city_tourism_populated.Museum, german_city_tourism_populated.BadWeatherOption, german_city_tourism_populated.OpenOnWeekend}
# * Owlready * Reparenting german_city_tourism_populated.venue_galerie_zh_1463: {german_city_tourism_populated.BudgetFriendlyActivity, german_city_tourism_populated.Museum, german_city_tourism_populated.RainyDayOption} => {german_city_tourism_populated.BudgetFriendlyActivity, german_city_tourism_populated.RainyDayOption, german_city_tourism_populated.Museum, german_city_tourism_populated.BadWeatherOption}
# * Owlready * Reparenting german_city_tourism_populated.venue_nordstadtgalerie_dortmund_1699: {german_city_tourism_populated.BudgetFriendlyActivity, german_city_tourism_populated.Museum, german_city_tourism_populated.RainyDayOption} => {german_city_tourism_populated.BudgetFriendlyActivity, german_city_tourism_populated.RainyDayOption, german_city_tourism_populated.Museum, german_city_tourism_populated.BadWeatherOption}
# * Owlready * Reparenting german_city_tourism_populated.venue_körperwelten_museum_facetten_des_lebens_82: {german_city_tourism_populated.Museum, german_city_tourism_populated.RainyDayOption} => {german_city_tourism_populated.RainyDayOption, german_city_tourism_populated.Museum, german_city_tourism_populated.BadWeatherOption, german_city_tourism_populated.OpenOnWeekend}
# * Owlready * Reparenting german_city_tourism_populated.venue_fernsehturm_stuttgart_1161: {german_city_tourism_populated.Sight, german_city_tourism_populated.RainyDayOption} => {german_city_tourism_populated.RainyDayOption, german_city_tourism_populated.OpenOnWeekend, german_city_tourism_populated.Sight, german_city_tourism_populated.BadWeatherOption}
# * Owlready * Reparenting german_city_tourism_populated.venue_johannes_brahms_museum_798: {german_city_tourism_populated.Museum, german_city_tourism_populated.RainyDayOption} => {german_city_tourism_populated.RainyDayOption, german_city_tourism_populated.Museum, german_city_tourism_populated.BadWeatherOption}
# * Owlready * Reparenting german_city_tourism_populated.venue_zigarrentraum_380: {german_city_tourism_populated.BudgetFriendlyActivity, german_city_tourism_populated.NightlifeVenue, german_city_tourism_populated.RainyDayOption} => {german_city_tourism_populated.BudgetFriendlyActivity, german_city_tourism_populated.RainyDayOption, german_city_tourism_populated.NightlifeVenue, german_city_tourism_populated.BadWeatherOption, german_city_tourism_populated.OpenOnWeekend}
# * Owlready * Reparenting german_city_tourism_populated.venue_altona_city_hall_756: {german_city_tourism_populated.BudgetFriendlyActivity, german_city_tourism_populated.Sight, german_city_tourism_populated.RainyDayOption} => {german_city_tourism_populated.BudgetFriendlyActivity, german_city_tourism_populated.RainyDayOption, german_city_tourism_populated.Sight, german_city_tourism_populated.BadWeatherOption}
# * Owlready * Reparenting german_city_tourism_populated.venue_cafe_banane_1720: {german_city_tourism_populated.BudgetFriendlyActivity, german_city_tourism_populated.NightlifeVenue, german_city_tourism_populated.RainyDayOption} => {german_city_tourism_populated.BudgetFriendlyActivity, german_city_tourism_populated.RainyDayOption, german_city_tourism_populated.NightlifeVenue, german_city_tourism_populated.BadWeatherOption}
# * Owlready * Reparenting german_city_tourism_populated.venue_the_corner_1300: {german_city_tourism_populated.BudgetFriendlyActivity, german_city_tourism_populated.NightlifeVenue, german_city_tourism_populated.RainyDayOption} => {german_city_tourism_populated.BudgetFriendlyActivity, german_city_tourism_populated.RainyDayOption, german_city_tourism_populated.NightlifeVenue, german_city_tourism_populated.BadWeatherOption, german_city_tourism_populated.OpenOnWeekend}
# * Owlready * Reparenting german_city_tourism_populated.venue_the_chug_club_839: {german_city_tourism_populated.BudgetFriendlyActivity, german_city_tourism_populated.NightlifeVenue, german_city_tourism_populated.RainyDayOption} => {german_city_tourism_populated.BudgetFriendlyActivity, german_city_tourism_populated.RainyDayOption, german_city_tourism_populated.NightlifeVenue, german_city_tourism_populated.BadWeatherOption, german_city_tourism_populated.OpenOnWeekend}
# * Owlready * Reparenting german_city_tourism_populated.venue_werdener_kräuter_und_heilpflanzengarten_1911: {german_city_tourism_populated.BudgetFriendlyActivity, german_city_tourism_populated.Park, german_city_tourism_populated.FamilyFriendlyActivity} => {german_city_tourism_populated.BudgetFriendlyActivity, german_city_tourism_populated.FamilyFriendlyActivity, german_city_tourism_populated.Park, german_city_tourism_populated.OpenOnWeekend}
# * Owlready * Reparenting german_city_tourism_populated.venue_the_wall_museum_96: {german_city_tourism_populated.Museum, german_city_tourism_populated.RainyDayOption} => {german_city_tourism_populated.RainyDayOption, german_city_tourism_populated.Museum, german_city_tourism_populated.BadWeatherOption, german_city_tourism_populated.OpenOnWeekend}
# * Owlready * Reparenting german_city_tourism_populated.venue_dussel_1592: {german_city_tourism_populated.BudgetFriendlyActivity, german_city_tourism_populated.Park, german_city_tourism_populated.FamilyFriendlyActivity} => {german_city_tourism_populated.BudgetFriendlyActivity, german_city_tourism_populated.FamilyFriendlyActivity, german_city_tourism_populated.Park, german_city_tourism_populated.OpenOnWeekend}
# * Owlready * Reparenting german_city_tourism_populated.venue_museum_schnütgen_305: {german_city_tourism_populated.BudgetFriendlyActivity, german_city_tourism_populated.Museum, german_city_tourism_populated.RainyDayOption} => {german_city_tourism_populated.BudgetFriendlyActivity, german_city_tourism_populated.RainyDayOption, german_city_tourism_populated.Museum, german_city_tourism_populated.BadWeatherOption, german_city_tourism_populated.OpenOnWeekend}
# * Owlready * Reparenting german_city_tourism_populated.venue_carl_zeiss_planetarium_1228: {german_city_tourism_populated.BudgetFriendlyActivity, german_city_tourism_populated.Museum, german_city_tourism_populated.RainyDayOption} => {german_city_tourism_populated.BudgetFriendlyActivity, german_city_tourism_populated.RainyDayOption, german_city_tourism_populated.Museum, german_city_tourism_populated.BadWeatherOption, german_city_tourism_populated.OpenOnWeekend}
# * Owlready * Reparenting german_city_tourism_populated.venue_palmengarten_frankfurt_1125: {german_city_tourism_populated.BudgetFriendlyActivity, german_city_tourism_populated.Park, german_city_tourism_populated.FamilyFriendlyActivity} => {german_city_tourism_populated.BudgetFriendlyActivity, german_city_tourism_populated.FamilyFriendlyActivity, german_city_tourism_populated.Park, german_city_tourism_populated.OpenOnWeekend}
# * Owlready * Reparenting german_city_tourism_populated.venue_lempertz_auction_house_cologne_332: {german_city_tourism_populated.BudgetFriendlyActivity, german_city_tourism_populated.Museum, german_city_tourism_populated.RainyDayOption} => {german_city_tourism_populated.BudgetFriendlyActivity, german_city_tourism_populated.RainyDayOption, german_city_tourism_populated.Museum, german_city_tourism_populated.BadWeatherOption}
# * Owlready * Reparenting german_city_tourism_populated.venue_flughafen_stuttgart_besucherterrasse_1181: {german_city_tourism_populated.BudgetFriendlyActivity, german_city_tourism_populated.Sight} => {german_city_tourism_populated.BudgetFriendlyActivity, german_city_tourism_populated.Sight, german_city_tourism_populated.OpenOnWeekend}
# * Owlready * Reparenting german_city_tourism_populated.venue_heinrich_heine_institute_1461: {german_city_tourism_populated.BudgetFriendlyActivity, german_city_tourism_populated.Museum, german_city_tourism_populated.RainyDayOption} => {german_city_tourism_populated.BudgetFriendlyActivity, german_city_tourism_populated.RainyDayOption, german_city_tourism_populated.Museum, german_city_tourism_populated.BadWeatherOption, german_city_tourism_populated.OpenOnWeekend}
# * Owlready * Reparenting german_city_tourism_populated.venue_bibliorama_das_bibelmuseum_stuttgart_1245: {german_city_tourism_populated.BudgetFriendlyActivity, german_city_tourism_populated.Museum, german_city_tourism_populated.RainyDayOption} => {german_city_tourism_populated.BudgetFriendlyActivity, german_city_tourism_populated.RainyDayOption, german_city_tourism_populated.Museum, german_city_tourism_populated.BadWeatherOption}
# * Owlready * Reparenting german_city_tourism_populated.venue_german_museum_of_technology_67: {german_city_tourism_populated.BudgetFriendlyActivity, german_city_tourism_populated.Museum, german_city_tourism_populated.RainyDayOption} => {german_city_tourism_populated.BudgetFriendlyActivity, german_city_tourism_populated.RainyDayOption, german_city_tourism_populated.Museum, german_city_tourism_populated.BadWeatherOption, german_city_tourism_populated.OpenOnWeekend}
# * Owlready * Reparenting german_city_tourism_populated.venue_dialog_im_stillen_787: {german_city_tourism_populated.Museum, german_city_tourism_populated.RainyDayOption} => {german_city_tourism_populated.RainyDayOption, german_city_tourism_populated.Museum, german_city_tourism_populated.BadWeatherOption, german_city_tourism_populated.OpenOnWeekend}
# * Owlready * Reparenting german_city_tourism_populated.venue_palace_square_1160: {german_city_tourism_populated.BudgetFriendlyActivity, german_city_tourism_populated.Sight} => {german_city_tourism_populated.BudgetFriendlyActivity, german_city_tourism_populated.Sight, german_city_tourism_populated.OpenOnWeekend}
# * Owlready * Reparenting german_city_tourism_populated.venue_mercedes_benz_museum_1159: {german_city_tourism_populated.Sight, german_city_tourism_populated.RainyDayOption} => {german_city_tourism_populated.RainyDayOption, german_city_tourism_populated.OpenOnWeekend, german_city_tourism_populated.Sight, german_city_tourism_populated.BadWeatherOption}
# * Owlready * Reparenting german_city_tourism_populated.venue_strobels_1710: {german_city_tourism_populated.BudgetFriendlyActivity, german_city_tourism_populated.NightlifeVenue, german_city_tourism_populated.RainyDayOption} => {german_city_tourism_populated.BudgetFriendlyActivity, german_city_tourism_populated.RainyDayOption, german_city_tourism_populated.NightlifeVenue, german_city_tourism_populated.BadWeatherOption, german_city_tourism_populated.OpenOnWeekend}
# * Owlready * Reparenting german_city_tourism_populated.venue_caipi_colada_bar_844: {german_city_tourism_populated.BudgetFriendlyActivity, german_city_tourism_populated.NightlifeVenue, german_city_tourism_populated.RainyDayOption} => {german_city_tourism_populated.BudgetFriendlyActivity, german_city_tourism_populated.RainyDayOption, german_city_tourism_populated.NightlifeVenue, german_city_tourism_populated.BadWeatherOption}
# * Owlready * Reparenting german_city_tourism_populated.venue_museum_judengasse_1015: {german_city_tourism_populated.BudgetFriendlyActivity, german_city_tourism_populated.Museum, german_city_tourism_populated.RainyDayOption} => {german_city_tourism_populated.BudgetFriendlyActivity, german_city_tourism_populated.RainyDayOption, german_city_tourism_populated.Museum, german_city_tourism_populated.BadWeatherOption, german_city_tourism_populated.OpenOnWeekend}
# * Owlready * Reparenting german_city_tourism_populated.venue_colmar_schulte_goltz_1832: {german_city_tourism_populated.BudgetFriendlyActivity, german_city_tourism_populated.Museum, german_city_tourism_populated.RainyDayOption} => {german_city_tourism_populated.BudgetFriendlyActivity, german_city_tourism_populated.RainyDayOption, german_city_tourism_populated.Museum, german_city_tourism_populated.BadWeatherOption}
# * Owlready * Reparenting german_city_tourism_populated.venue_david_quelle_867: {german_city_tourism_populated.BudgetFriendlyActivity, german_city_tourism_populated.NightlifeVenue, german_city_tourism_populated.RainyDayOption} => {german_city_tourism_populated.BudgetFriendlyActivity, german_city_tourism_populated.RainyDayOption, german_city_tourism_populated.NightlifeVenue, german_city_tourism_populated.BadWeatherOption}
# * Owlready * Reparenting german_city_tourism_populated.venue_old_fashioned_kultur_tanz_bar_1069: {german_city_tourism_populated.BudgetFriendlyActivity, german_city_tourism_populated.NightlifeVenue, german_city_tourism_populated.RainyDayOption} => {german_city_tourism_populated.BudgetFriendlyActivity, german_city_tourism_populated.RainyDayOption, german_city_tourism_populated.NightlifeVenue, german_city_tourism_populated.BadWeatherOption}
# * Owlready * Reparenting german_city_tourism_populated.venue_mggu_museum_giersch_der_goethe_universität_1032: {german_city_tourism_populated.BudgetFriendlyActivity, german_city_tourism_populated.Museum, german_city_tourism_populated.RainyDayOption} => {german_city_tourism_populated.BudgetFriendlyActivity, german_city_tourism_populated.RainyDayOption, german_city_tourism_populated.Museum, german_city_tourism_populated.BadWeatherOption, german_city_tourism_populated.OpenOnWeekend}
# * Owlready * Reparenting german_city_tourism_populated.venue_viaggio_vespina_458: {german_city_tourism_populated.BudgetFriendlyActivity, german_city_tourism_populated.Park, german_city_tourism_populated.FamilyFriendlyActivity} => {german_city_tourism_populated.BudgetFriendlyActivity, german_city_tourism_populated.FamilyFriendlyActivity, german_city_tourism_populated.Park, german_city_tourism_populated.OpenOnWeekend}
# * Owlready * Reparenting german_city_tourism_populated.venue_medizinhistorisches_museum_319: {german_city_tourism_populated.BudgetFriendlyActivity, german_city_tourism_populated.Museum, german_city_tourism_populated.RainyDayOption} => {german_city_tourism_populated.BudgetFriendlyActivity, german_city_tourism_populated.RainyDayOption, german_city_tourism_populated.Museum, german_city_tourism_populated.BadWeatherOption}
# * Owlready * Reparenting german_city_tourism_populated.venue_spielbank_stuttgart_1281: {german_city_tourism_populated.BudgetFriendlyActivity, german_city_tourism_populated.NightlifeVenue, german_city_tourism_populated.RainyDayOption} => {german_city_tourism_populated.BudgetFriendlyActivity, german_city_tourism_populated.RainyDayOption, german_city_tourism_populated.NightlifeVenue, german_city_tourism_populated.BadWeatherOption}
# * Owlready * Reparenting german_city_tourism_populated.venue_its_art_baby_1457: {german_city_tourism_populated.BudgetFriendlyActivity, german_city_tourism_populated.Museum, german_city_tourism_populated.RainyDayOption} => {german_city_tourism_populated.BudgetFriendlyActivity, german_city_tourism_populated.RainyDayOption, german_city_tourism_populated.Museum, german_city_tourism_populated.BadWeatherOption}
# * Owlready * Reparenting german_city_tourism_populated.venue_peter_guest_kräuter_gallery_592: {german_city_tourism_populated.BudgetFriendlyActivity, german_city_tourism_populated.Museum, german_city_tourism_populated.RainyDayOption} => {german_city_tourism_populated.BudgetFriendlyActivity, german_city_tourism_populated.RainyDayOption, german_city_tourism_populated.Museum, german_city_tourism_populated.BadWeatherOption}
# * Owlready * Reparenting german_city_tourism_populated.venue_bella_billard_639: {german_city_tourism_populated.BudgetFriendlyActivity, german_city_tourism_populated.NightlifeVenue, german_city_tourism_populated.RainyDayOption} => {german_city_tourism_populated.BudgetFriendlyActivity, german_city_tourism_populated.RainyDayOption, german_city_tourism_populated.NightlifeVenue, german_city_tourism_populated.BadWeatherOption}
# * Owlready * Reparenting german_city_tourism_populated.venue_limonadier_163: {german_city_tourism_populated.BudgetFriendlyActivity, german_city_tourism_populated.NightlifeVenue, german_city_tourism_populated.RainyDayOption} => {german_city_tourism_populated.BudgetFriendlyActivity, german_city_tourism_populated.RainyDayOption, german_city_tourism_populated.NightlifeVenue, german_city_tourism_populated.BadWeatherOption, german_city_tourism_populated.OpenOnWeekend}
# * Owlready * Reparenting german_city_tourism_populated.venue_st_pauls_church_507: {german_city_tourism_populated.BudgetFriendlyActivity, german_city_tourism_populated.Sight, german_city_tourism_populated.RainyDayOption} => {german_city_tourism_populated.BudgetFriendlyActivity, german_city_tourism_populated.RainyDayOption, german_city_tourism_populated.Sight, german_city_tourism_populated.BadWeatherOption}
# * Owlready * Reparenting german_city_tourism_populated.venue_dom_museum_1026: {german_city_tourism_populated.BudgetFriendlyActivity, german_city_tourism_populated.Museum, german_city_tourism_populated.RainyDayOption} => {german_city_tourism_populated.BudgetFriendlyActivity, german_city_tourism_populated.RainyDayOption, german_city_tourism_populated.Museum, german_city_tourism_populated.BadWeatherOption}
# * Owlready * Reparenting german_city_tourism_populated.venue_phönix_sauna_365: {german_city_tourism_populated.NightlifeVenue, german_city_tourism_populated.RainyDayOption} => {german_city_tourism_populated.RainyDayOption, german_city_tourism_populated.NightlifeVenue, german_city_tourism_populated.BadWeatherOption, german_city_tourism_populated.OpenOnWeekend}
# * Owlready * Reparenting german_city_tourism_populated.venue_mondo_mio_kindermuseum_1676: {german_city_tourism_populated.BudgetFriendlyActivity, german_city_tourism_populated.Museum, german_city_tourism_populated.RainyDayOption} => {german_city_tourism_populated.BudgetFriendlyActivity, german_city_tourism_populated.RainyDayOption, german_city_tourism_populated.Museum, german_city_tourism_populated.BadWeatherOption, german_city_tourism_populated.OpenOnWeekend}
# * Owlready * Reparenting german_city_tourism_populated.venue_monster_ronsons_ichiban_karaoke_162: {german_city_tourism_populated.BudgetFriendlyActivity, german_city_tourism_populated.NightlifeVenue, german_city_tourism_populated.RainyDayOption} => {german_city_tourism_populated.BudgetFriendlyActivity, german_city_tourism_populated.RainyDayOption, german_city_tourism_populated.NightlifeVenue, german_city_tourism_populated.BadWeatherOption, german_city_tourism_populated.OpenOnWeekend}
# * Owlready * Reparenting german_city_tourism_populated.venue_lanxess_arena_241: {german_city_tourism_populated.BudgetFriendlyActivity, german_city_tourism_populated.Sight, german_city_tourism_populated.RainyDayOption} => {german_city_tourism_populated.BudgetFriendlyActivity, german_city_tourism_populated.RainyDayOption, german_city_tourism_populated.Sight, german_city_tourism_populated.BadWeatherOption}
# * Owlready * Reparenting german_city_tourism_populated.venue_killesbergturm_1168: {german_city_tourism_populated.BudgetFriendlyActivity, german_city_tourism_populated.Sight} => {german_city_tourism_populated.BudgetFriendlyActivity, german_city_tourism_populated.Sight, german_city_tourism_populated.OpenOnWeekend}
# * Owlready * Reparenting german_city_tourism_populated.venue_friedensplatz_1643: {german_city_tourism_populated.BudgetFriendlyActivity, german_city_tourism_populated.Sight} => {german_city_tourism_populated.BudgetFriendlyActivity, german_city_tourism_populated.Sight, german_city_tourism_populated.OpenOnWeekend}
# * Owlready * Reparenting german_city_tourism_populated.venue_jeck_377: {german_city_tourism_populated.BudgetFriendlyActivity, german_city_tourism_populated.NightlifeVenue, german_city_tourism_populated.RainyDayOption} => {german_city_tourism_populated.BudgetFriendlyActivity, german_city_tourism_populated.RainyDayOption, german_city_tourism_populated.NightlifeVenue, german_city_tourism_populated.BadWeatherOption}
# * Owlready * Reparenting german_city_tourism_populated.venue_frechdachs_indoorspielplatz_1366: {german_city_tourism_populated.Park, german_city_tourism_populated.FamilyFriendlyActivity, german_city_tourism_populated.RainyDayOption} => {german_city_tourism_populated.FamilyFriendlyActivity, german_city_tourism_populated.RainyDayOption, german_city_tourism_populated.Park, german_city_tourism_populated.BadWeatherOption}
# * Owlready * Reparenting german_city_tourism_populated.venue_wasserspielplatz_424: {german_city_tourism_populated.BudgetFriendlyActivity, german_city_tourism_populated.Park, german_city_tourism_populated.FamilyFriendlyActivity} => {german_city_tourism_populated.BudgetFriendlyActivity, german_city_tourism_populated.FamilyFriendlyActivity, german_city_tourism_populated.Park, german_city_tourism_populated.OpenOnWeekend}
# * Owlready * Reparenting german_city_tourism_populated.venue_trash_chic_374: {german_city_tourism_populated.BudgetFriendlyActivity, german_city_tourism_populated.NightlifeVenue, german_city_tourism_populated.RainyDayOption} => {german_city_tourism_populated.BudgetFriendlyActivity, german_city_tourism_populated.RainyDayOption, german_city_tourism_populated.NightlifeVenue, german_city_tourism_populated.BadWeatherOption, german_city_tourism_populated.OpenOnWeekend}
# * Owlready * Reparenting german_city_tourism_populated.tour_munich_guided_tour_of_the_historic_town_hall_on_marienplatz_351: {german_city_tourism_populated.EnglishFriendlyTour, german_city_tourism_populated.RainyDayOption} => {german_city_tourism_populated.EnglishFriendlyTour, german_city_tourism_populated.RainyDayOption, german_city_tourism_populated.BadWeatherOption}
# * Owlready * Reparenting german_city_tourism_populated.venue_volkspark_jungfernheide_226: {german_city_tourism_populated.BudgetFriendlyActivity, german_city_tourism_populated.Park, german_city_tourism_populated.FamilyFriendlyActivity} => {german_city_tourism_populated.BudgetFriendlyActivity, german_city_tourism_populated.FamilyFriendlyActivity, german_city_tourism_populated.Park, german_city_tourism_populated.OpenOnWeekend}
# * Owlready * Reparenting german_city_tourism_populated.venue_machmit_museum_für_kinder_108: {german_city_tourism_populated.BudgetFriendlyActivity, german_city_tourism_populated.Museum, german_city_tourism_populated.RainyDayOption} => {german_city_tourism_populated.BudgetFriendlyActivity, german_city_tourism_populated.RainyDayOption, german_city_tourism_populated.Museum, german_city_tourism_populated.BadWeatherOption, german_city_tourism_populated.OpenOnWeekend}
# * Owlready * Reparenting german_city_tourism_populated.venue_deutsche_kinemathek_109: {german_city_tourism_populated.BudgetFriendlyActivity, german_city_tourism_populated.Museum, german_city_tourism_populated.RainyDayOption} => {german_city_tourism_populated.BudgetFriendlyActivity, german_city_tourism_populated.RainyDayOption, german_city_tourism_populated.Museum, german_city_tourism_populated.BadWeatherOption}
# * Owlready * Reparenting german_city_tourism_populated.venue_vertigo_623: {german_city_tourism_populated.BudgetFriendlyActivity, german_city_tourism_populated.NightlifeVenue, german_city_tourism_populated.RainyDayOption} => {german_city_tourism_populated.BudgetFriendlyActivity, german_city_tourism_populated.RainyDayOption, german_city_tourism_populated.NightlifeVenue, german_city_tourism_populated.BadWeatherOption}
# * Owlready * Reparenting german_city_tourism_populated.venue_schwabengalerie_1258: {german_city_tourism_populated.BudgetFriendlyActivity, german_city_tourism_populated.Museum, german_city_tourism_populated.RainyDayOption} => {german_city_tourism_populated.BudgetFriendlyActivity, german_city_tourism_populated.RainyDayOption, german_city_tourism_populated.Museum, german_city_tourism_populated.BadWeatherOption}
# * Owlready * Reparenting german_city_tourism_populated.venue_markthalle_845: {german_city_tourism_populated.NightlifeVenue, german_city_tourism_populated.RainyDayOption} => {german_city_tourism_populated.RainyDayOption, german_city_tourism_populated.NightlifeVenue, german_city_tourism_populated.BadWeatherOption}
# * Owlready * Reparenting german_city_tourism_populated.tour_german_football_museum_106: {german_city_tourism_populated.Tour, german_city_tourism_populated.RainyDayOption} => {german_city_tourism_populated.RainyDayOption, german_city_tourism_populated.Tour, german_city_tourism_populated.BadWeatherOption}
# * Owlready * Reparenting german_city_tourism_populated.venue_westfalenhalle_1_1631: {german_city_tourism_populated.Sight, german_city_tourism_populated.RainyDayOption} => {german_city_tourism_populated.RainyDayOption, german_city_tourism_populated.Sight, german_city_tourism_populated.BadWeatherOption}
# * Owlready * Reparenting german_city_tourism_populated.venue_madame_claude_bar_161: {german_city_tourism_populated.BudgetFriendlyActivity, german_city_tourism_populated.NightlifeVenue, german_city_tourism_populated.RainyDayOption} => {german_city_tourism_populated.BudgetFriendlyActivity, german_city_tourism_populated.RainyDayOption, german_city_tourism_populated.NightlifeVenue, german_city_tourism_populated.BadWeatherOption}
# * Owlready * Reparenting german_city_tourism_populated.venue_edelheiss_munchen_602: {german_city_tourism_populated.BudgetFriendlyActivity, german_city_tourism_populated.NightlifeVenue, german_city_tourism_populated.RainyDayOption} => {german_city_tourism_populated.BudgetFriendlyActivity, german_city_tourism_populated.RainyDayOption, german_city_tourism_populated.NightlifeVenue, german_city_tourism_populated.BadWeatherOption, german_city_tourism_populated.OpenOnWeekend}
# * Owlready * Reparenting german_city_tourism_populated.venue_st_georg_muenchen_bogenhausen_528: {german_city_tourism_populated.BudgetFriendlyActivity, german_city_tourism_populated.Sight, german_city_tourism_populated.RainyDayOption} => {german_city_tourism_populated.BudgetFriendlyActivity, german_city_tourism_populated.RainyDayOption, german_city_tourism_populated.Sight, german_city_tourism_populated.BadWeatherOption}
# * Owlready * Reparenting german_city_tourism_populated.venue_ccaa_glasgalerie_köln_347: {german_city_tourism_populated.BudgetFriendlyActivity, german_city_tourism_populated.Museum, german_city_tourism_populated.RainyDayOption} => {german_city_tourism_populated.BudgetFriendlyActivity, german_city_tourism_populated.RainyDayOption, german_city_tourism_populated.Museum, german_city_tourism_populated.BadWeatherOption}
# * Owlready * Reparenting german_city_tourism_populated.venue_hunky_dory_bar_1067: {german_city_tourism_populated.BudgetFriendlyActivity, german_city_tourism_populated.NightlifeVenue, german_city_tourism_populated.RainyDayOption} => {german_city_tourism_populated.BudgetFriendlyActivity, german_city_tourism_populated.RainyDayOption, german_city_tourism_populated.NightlifeVenue, german_city_tourism_populated.BadWeatherOption}
# * Owlready * Reparenting german_city_tourism_populated.venue_jenischhaus_806: {german_city_tourism_populated.BudgetFriendlyActivity, german_city_tourism_populated.Museum, german_city_tourism_populated.RainyDayOption} => {german_city_tourism_populated.BudgetFriendlyActivity, german_city_tourism_populated.RainyDayOption, german_city_tourism_populated.Museum, german_city_tourism_populated.BadWeatherOption, german_city_tourism_populated.OpenOnWeekend}
# * Owlready * Reparenting german_city_tourism_populated.venue_mirrors_cocktailbar_lounge_1511: {german_city_tourism_populated.BudgetFriendlyActivity, german_city_tourism_populated.NightlifeVenue, german_city_tourism_populated.RainyDayOption} => {german_city_tourism_populated.BudgetFriendlyActivity, german_city_tourism_populated.RainyDayOption, german_city_tourism_populated.NightlifeVenue, german_city_tourism_populated.BadWeatherOption}
# * Owlready * Reparenting german_city_tourism_populated.venue_hamburger_museum_114: {german_city_tourism_populated.Museum, german_city_tourism_populated.RainyDayOption} => {german_city_tourism_populated.RainyDayOption, german_city_tourism_populated.Museum, german_city_tourism_populated.BadWeatherOption, german_city_tourism_populated.OpenOnWeekend}
# * Owlready * Reparenting german_city_tourism_populated.venue_puf_1293: {german_city_tourism_populated.BudgetFriendlyActivity, german_city_tourism_populated.NightlifeVenue, german_city_tourism_populated.RainyDayOption} => {german_city_tourism_populated.BudgetFriendlyActivity, german_city_tourism_populated.RainyDayOption, german_city_tourism_populated.NightlifeVenue, german_city_tourism_populated.BadWeatherOption}
# * Owlready * Reparenting german_city_tourism_populated.venue_archaeological_zone_jewish_museum_337: {german_city_tourism_populated.BudgetFriendlyActivity, german_city_tourism_populated.Museum, german_city_tourism_populated.RainyDayOption} => {german_city_tourism_populated.BudgetFriendlyActivity, german_city_tourism_populated.RainyDayOption, german_city_tourism_populated.Museum, german_city_tourism_populated.BadWeatherOption}
# * Owlready * Reparenting german_city_tourism_populated.venue_kölner_karnevalsmuseum_324: {german_city_tourism_populated.BudgetFriendlyActivity, german_city_tourism_populated.Museum, german_city_tourism_populated.RainyDayOption} => {german_city_tourism_populated.BudgetFriendlyActivity, german_city_tourism_populated.RainyDayOption, german_city_tourism_populated.Museum, german_city_tourism_populated.BadWeatherOption}
# * Owlready * Reparenting german_city_tourism_populated.venue_apfelweinkontor_1104: {german_city_tourism_populated.BudgetFriendlyActivity, german_city_tourism_populated.NightlifeVenue, german_city_tourism_populated.RainyDayOption} => {german_city_tourism_populated.BudgetFriendlyActivity, german_city_tourism_populated.RainyDayOption, german_city_tourism_populated.NightlifeVenue, german_city_tourism_populated.BadWeatherOption, german_city_tourism_populated.OpenOnWeekend}
# * Owlready * Reparenting german_city_tourism_populated.venue_monsterkabinett_89: {german_city_tourism_populated.BudgetFriendlyActivity, german_city_tourism_populated.Museum, german_city_tourism_populated.RainyDayOption} => {german_city_tourism_populated.BudgetFriendlyActivity, german_city_tourism_populated.RainyDayOption, german_city_tourism_populated.Museum, german_city_tourism_populated.BadWeatherOption, german_city_tourism_populated.OpenOnWeekend}
# * Owlready * Reparenting german_city_tourism_populated.venue_kunstmuseum_stuttgart_1225: {german_city_tourism_populated.BudgetFriendlyActivity, german_city_tourism_populated.Museum, german_city_tourism_populated.RainyDayOption} => {german_city_tourism_populated.BudgetFriendlyActivity, german_city_tourism_populated.RainyDayOption, german_city_tourism_populated.Museum, german_city_tourism_populated.BadWeatherOption, german_city_tourism_populated.OpenOnWeekend}
# * Owlready * Reparenting german_city_tourism_populated.venue_tierbestattung_andré_kuth_trauer_mit_herz_1645: {german_city_tourism_populated.BudgetFriendlyActivity, german_city_tourism_populated.Sight, german_city_tourism_populated.RainyDayOption} => {german_city_tourism_populated.BudgetFriendlyActivity, german_city_tourism_populated.RainyDayOption, german_city_tourism_populated.OpenOnWeekend, german_city_tourism_populated.Sight, german_city_tourism_populated.BadWeatherOption}
# * Owlready * Reparenting german_city_tourism_populated.venue_grune_scheune_1119: {german_city_tourism_populated.NightlifeVenue, german_city_tourism_populated.RainyDayOption} => {german_city_tourism_populated.RainyDayOption, german_city_tourism_populated.NightlifeVenue, german_city_tourism_populated.BadWeatherOption}
# * Owlready * Reparenting german_city_tourism_populated.venue_rosenstein_park_1349: {german_city_tourism_populated.BudgetFriendlyActivity, german_city_tourism_populated.Park, german_city_tourism_populated.FamilyFriendlyActivity} => {german_city_tourism_populated.BudgetFriendlyActivity, german_city_tourism_populated.FamilyFriendlyActivity, german_city_tourism_populated.Park, german_city_tourism_populated.OpenOnWeekend}
# * Owlready * Reparenting german_city_tourism_populated.venue_stereo_karaokebar_1289: {german_city_tourism_populated.BudgetFriendlyActivity, german_city_tourism_populated.NightlifeVenue, german_city_tourism_populated.RainyDayOption} => {german_city_tourism_populated.BudgetFriendlyActivity, german_city_tourism_populated.RainyDayOption, german_city_tourism_populated.NightlifeVenue, german_city_tourism_populated.BadWeatherOption, german_city_tourism_populated.OpenOnWeekend}
# * Owlready * Reparenting german_city_tourism_populated.venue_jüdisches_museum_frankfurt_1020: {german_city_tourism_populated.BudgetFriendlyActivity, german_city_tourism_populated.Museum, german_city_tourism_populated.RainyDayOption} => {german_city_tourism_populated.BudgetFriendlyActivity, german_city_tourism_populated.RainyDayOption, german_city_tourism_populated.Museum, german_city_tourism_populated.BadWeatherOption, german_city_tourism_populated.OpenOnWeekend}
# * Owlready * Reparenting german_city_tourism_populated.venue_palace_of_tears_72: {german_city_tourism_populated.BudgetFriendlyActivity, german_city_tourism_populated.Museum, german_city_tourism_populated.RainyDayOption} => {german_city_tourism_populated.BudgetFriendlyActivity, german_city_tourism_populated.RainyDayOption, german_city_tourism_populated.Museum, german_city_tourism_populated.BadWeatherOption, german_city_tourism_populated.OpenOnWeekend}
# * Owlready * Reparenting german_city_tourism_populated.venue_pfarrkirche_st_nikolas_am_stoppenberg_1798: {german_city_tourism_populated.BudgetFriendlyActivity, german_city_tourism_populated.Sight, german_city_tourism_populated.RainyDayOption} => {german_city_tourism_populated.BudgetFriendlyActivity, german_city_tourism_populated.RainyDayOption, german_city_tourism_populated.Sight, german_city_tourism_populated.BadWeatherOption}
# * Owlready * Reparenting german_city_tourism_populated.venue_cafe_goldbar_1871: {german_city_tourism_populated.BudgetFriendlyActivity, german_city_tourism_populated.NightlifeVenue, german_city_tourism_populated.RainyDayOption} => {german_city_tourism_populated.BudgetFriendlyActivity, german_city_tourism_populated.RainyDayOption, german_city_tourism_populated.NightlifeVenue, german_city_tourism_populated.BadWeatherOption}
# * Owlready * Reparenting german_city_tourism_populated.venue_ballinstadt_emigration_museum_hamburg_784: {german_city_tourism_populated.Museum, german_city_tourism_populated.RainyDayOption} => {german_city_tourism_populated.RainyDayOption, german_city_tourism_populated.Museum, german_city_tourism_populated.BadWeatherOption, german_city_tourism_populated.OpenOnWeekend}
# * Owlready * Reparenting german_city_tourism_populated.venue_tribal_art_kortmann_1703: {german_city_tourism_populated.BudgetFriendlyActivity, german_city_tourism_populated.Museum, german_city_tourism_populated.RainyDayOption} => {german_city_tourism_populated.BudgetFriendlyActivity, german_city_tourism_populated.RainyDayOption, german_city_tourism_populated.Museum, german_city_tourism_populated.BadWeatherOption}
# * Owlready * Reparenting german_city_tourism_populated.venue_fou_fou_1283: {german_city_tourism_populated.BudgetFriendlyActivity, german_city_tourism_populated.NightlifeVenue, german_city_tourism_populated.RainyDayOption} => {german_city_tourism_populated.BudgetFriendlyActivity, german_city_tourism_populated.RainyDayOption, german_city_tourism_populated.NightlifeVenue, german_city_tourism_populated.BadWeatherOption, german_city_tourism_populated.OpenOnWeekend}
# * Owlready * Reparenting german_city_tourism_populated.venue_musiklokal_südbahnhof_1099: {german_city_tourism_populated.NightlifeVenue, german_city_tourism_populated.RainyDayOption} => {german_city_tourism_populated.RainyDayOption, german_city_tourism_populated.NightlifeVenue, german_city_tourism_populated.BadWeatherOption}
# * Owlready * Reparenting german_city_tourism_populated.venue_kater_155: {german_city_tourism_populated.NightlifeVenue, german_city_tourism_populated.RainyDayOption} => {german_city_tourism_populated.RainyDayOption, german_city_tourism_populated.NightlifeVenue, german_city_tourism_populated.BadWeatherOption}
# * Owlready * Reparenting german_city_tourism_populated.venue_gärten_der_welt_180: {german_city_tourism_populated.BudgetFriendlyActivity, german_city_tourism_populated.Park, german_city_tourism_populated.FamilyFriendlyActivity} => {german_city_tourism_populated.BudgetFriendlyActivity, german_city_tourism_populated.FamilyFriendlyActivity, german_city_tourism_populated.Park, german_city_tourism_populated.OpenOnWeekend}
# * Owlready * Reparenting german_city_tourism_populated.venue_bayerischer_hof_night_club_599: {german_city_tourism_populated.BudgetFriendlyActivity, german_city_tourism_populated.NightlifeVenue, german_city_tourism_populated.RainyDayOption} => {german_city_tourism_populated.BudgetFriendlyActivity, german_city_tourism_populated.RainyDayOption, german_city_tourism_populated.NightlifeVenue, german_city_tourism_populated.BadWeatherOption, german_city_tourism_populated.OpenOnWeekend}
# * Owlready * Reparenting german_city_tourism_populated.venue_rot_vogel_1073: {german_city_tourism_populated.BudgetFriendlyActivity, german_city_tourism_populated.NightlifeVenue, german_city_tourism_populated.RainyDayOption} => {german_city_tourism_populated.BudgetFriendlyActivity, german_city_tourism_populated.RainyDayOption, german_city_tourism_populated.NightlifeVenue, german_city_tourism_populated.BadWeatherOption}
# * Owlready * Reparenting german_city_tourism_populated.venue_musiktheater_piano_1731: {german_city_tourism_populated.NightlifeVenue, german_city_tourism_populated.RainyDayOption} => {german_city_tourism_populated.RainyDayOption, german_city_tourism_populated.NightlifeVenue, german_city_tourism_populated.BadWeatherOption}
# * Owlready * Reparenting german_city_tourism_populated.venue_museum_fur_stuttgart_1256: {german_city_tourism_populated.BudgetFriendlyActivity, german_city_tourism_populated.Museum, german_city_tourism_populated.RainyDayOption} => {german_city_tourism_populated.BudgetFriendlyActivity, german_city_tourism_populated.RainyDayOption, german_city_tourism_populated.Museum, german_city_tourism_populated.BadWeatherOption}
# * Owlready * Reparenting german_city_tourism_populated.venue_römisch_germanisches_museum_im_belgischen_haus_317: {german_city_tourism_populated.BudgetFriendlyActivity, german_city_tourism_populated.Museum, german_city_tourism_populated.RainyDayOption} => {german_city_tourism_populated.BudgetFriendlyActivity, german_city_tourism_populated.RainyDayOption, german_city_tourism_populated.Museum, german_city_tourism_populated.BadWeatherOption}
# * Owlready * Reparenting german_city_tourism_populated.venue_sudrock_1866: {german_city_tourism_populated.BudgetFriendlyActivity, german_city_tourism_populated.NightlifeVenue, german_city_tourism_populated.RainyDayOption} => {german_city_tourism_populated.BudgetFriendlyActivity, german_city_tourism_populated.RainyDayOption, german_city_tourism_populated.NightlifeVenue, german_city_tourism_populated.BadWeatherOption}
# * Owlready * Reparenting german_city_tourism_populated.venue_cubanitos_bar_1507: {german_city_tourism_populated.BudgetFriendlyActivity, german_city_tourism_populated.NightlifeVenue, german_city_tourism_populated.RainyDayOption} => {german_city_tourism_populated.BudgetFriendlyActivity, german_city_tourism_populated.RainyDayOption, german_city_tourism_populated.NightlifeVenue, german_city_tourism_populated.BadWeatherOption, german_city_tourism_populated.OpenOnWeekend}
# ...
# * Owlready * Reparenting german_city_tourism_populated.venue_historic_town_hall_255: {german_city_tourism_populated.BudgetFriendlyActivity, german_city_tourism_populated.Sight, german_city_tourism_populated.RainyDayOption} => {german_city_tourism_populated.BudgetFriendlyActivity, german_city_tourism_populated.RainyDayOption, german_city_tourism_populated.Sight, german_city_tourism_populated.BadWeatherOption}
# * Owlready * Reparenting german_city_tourism_populated.venue_fox_bar_614: {german_city_tourism_populated.BudgetFriendlyActivity, german_city_tourism_populated.NightlifeVenue, german_city_tourism_populated.RainyDayOption} => {german_city_tourism_populated.BudgetFriendlyActivity, german_city_tourism_populated.RainyDayOption, german_city_tourism_populated.NightlifeVenue, german_city_tourism_populated.BadWeatherOption, german_city_tourism_populated.OpenOnWeekend}
# * Owlready * Reparenting german_city_tourism_populated.venue_thomaskirche_1813: {german_city_tourism_populated.BudgetFriendlyActivity, german_city_tourism_populated.Sight, german_city_tourism_populated.RainyDayOption} => {german_city_tourism_populated.BudgetFriendlyActivity, german_city_tourism_populated.RainyDayOption, german_city_tourism_populated.Sight, german_city_tourism_populated.BadWeatherOption}
# * Owlready * Reparenting german_city_tourism_populated.venue_schatzkammer_werden_1837: {german_city_tourism_populated.BudgetFriendlyActivity, german_city_tourism_populated.Museum, german_city_tourism_populated.RainyDayOption} => {german_city_tourism_populated.BudgetFriendlyActivity, german_city_tourism_populated.RainyDayOption, german_city_tourism_populated.Museum, german_city_tourism_populated.BadWeatherOption}
# * Owlready * Reparenting german_city_tourism_populated.venue_chocolate_museum_296: {german_city_tourism_populated.Museum, german_city_tourism_populated.RainyDayOption} => {german_city_tourism_populated.RainyDayOption, german_city_tourism_populated.Museum, german_city_tourism_populated.BadWeatherOption, german_city_tourism_populated.OpenOnWeekend}
# * Owlready * Reparenting german_city_tourism_populated.venue_spielplatz_schmalbeinstraße_453: {german_city_tourism_populated.BudgetFriendlyActivity, german_city_tourism_populated.Park, german_city_tourism_populated.FamilyFriendlyActivity} => {german_city_tourism_populated.BudgetFriendlyActivity, german_city_tourism_populated.FamilyFriendlyActivity, german_city_tourism_populated.Park, german_city_tourism_populated.OpenOnWeekend}
# * Owlready * Reparenting german_city_tourism_populated.venue_aussichtsturm_burgholzhof_1211: {german_city_tourism_populated.BudgetFriendlyActivity, german_city_tourism_populated.Sight} => {german_city_tourism_populated.BudgetFriendlyActivity, german_city_tourism_populated.Sight, german_city_tourism_populated.OpenOnWeekend}
# * Owlready * Reparenting german_city_tourism_populated.venue_gaststatte_auf_der_lauke_1734: {german_city_tourism_populated.BudgetFriendlyActivity, german_city_tourism_populated.NightlifeVenue, german_city_tourism_populated.RainyDayOption} => {german_city_tourism_populated.BudgetFriendlyActivity, german_city_tourism_populated.RainyDayOption, german_city_tourism_populated.NightlifeVenue, german_city_tourism_populated.BadWeatherOption}
# * Owlready * Reparenting german_city_tourism_populated.venue_de_prins_1880: {german_city_tourism_populated.BudgetFriendlyActivity, german_city_tourism_populated.NightlifeVenue, german_city_tourism_populated.RainyDayOption} => {german_city_tourism_populated.BudgetFriendlyActivity, german_city_tourism_populated.RainyDayOption, german_city_tourism_populated.NightlifeVenue, german_city_tourism_populated.BadWeatherOption}
# * Owlready * Reparenting german_city_tourism_populated.venue_hoesch_museum_1681: {german_city_tourism_populated.BudgetFriendlyActivity, german_city_tourism_populated.Museum, german_city_tourism_populated.RainyDayOption} => {german_city_tourism_populated.BudgetFriendlyActivity, german_city_tourism_populated.RainyDayOption, german_city_tourism_populated.Museum, german_city_tourism_populated.BadWeatherOption, german_city_tourism_populated.OpenOnWeekend}
# * Owlready * Reparenting german_city_tourism_populated.venue_illuseum_berlin_85: {german_city_tourism_populated.Museum, german_city_tourism_populated.RainyDayOption} => {german_city_tourism_populated.RainyDayOption, german_city_tourism_populated.Museum, german_city_tourism_populated.BadWeatherOption, german_city_tourism_populated.OpenOnWeekend}
# * Owlready * Reparenting german_city_tourism_populated.venue_spielplatz_grüngürtel_435: {german_city_tourism_populated.BudgetFriendlyActivity, german_city_tourism_populated.Park, german_city_tourism_populated.FamilyFriendlyActivity} => {german_city_tourism_populated.BudgetFriendlyActivity, german_city_tourism_populated.FamilyFriendlyActivity, german_city_tourism_populated.Park, german_city_tourism_populated.OpenOnWeekend}
# * Owlready * Reparenting german_city_tourism_populated.venue_hsv_museum_820: {german_city_tourism_populated.BudgetFriendlyActivity, german_city_tourism_populated.Museum, german_city_tourism_populated.RainyDayOption} => {german_city_tourism_populated.BudgetFriendlyActivity, german_city_tourism_populated.RainyDayOption, german_city_tourism_populated.Museum, german_city_tourism_populated.BadWeatherOption, german_city_tourism_populated.OpenOnWeekend}
# * Owlready * Reparenting german_city_tourism_populated.venue_tus_treff_dusseldorf_unterrath_1527: {german_city_tourism_populated.BudgetFriendlyActivity, german_city_tourism_populated.NightlifeVenue, german_city_tourism_populated.RainyDayOption} => {german_city_tourism_populated.BudgetFriendlyActivity, german_city_tourism_populated.RainyDayOption, german_city_tourism_populated.NightlifeVenue, german_city_tourism_populated.BadWeatherOption}
# * Owlready * Reparenting german_city_tourism_populated.venue_stairs_bar_160: {german_city_tourism_populated.BudgetFriendlyActivity, german_city_tourism_populated.NightlifeVenue, german_city_tourism_populated.RainyDayOption} => {german_city_tourism_populated.BudgetFriendlyActivity, german_city_tourism_populated.RainyDayOption, german_city_tourism_populated.NightlifeVenue, german_city_tourism_populated.BadWeatherOption, german_city_tourism_populated.OpenOnWeekend}
# * Owlready * Reparenting german_city_tourism_populated.venue_jvdw_gallery_1498: {german_city_tourism_populated.BudgetFriendlyActivity, german_city_tourism_populated.Museum, german_city_tourism_populated.RainyDayOption} => {german_city_tourism_populated.BudgetFriendlyActivity, german_city_tourism_populated.RainyDayOption, german_city_tourism_populated.Museum, german_city_tourism_populated.BadWeatherOption}
# * Owlready * Reparenting german_city_tourism_populated.venue_visitors_terrace_963: {german_city_tourism_populated.BudgetFriendlyActivity, german_city_tourism_populated.Sight} => {german_city_tourism_populated.BudgetFriendlyActivity, german_city_tourism_populated.Sight, german_city_tourism_populated.OpenOnWeekend}
# * Owlready * Reparenting german_city_tourism_populated.venue_shrine_of_the_three_kings_247: {german_city_tourism_populated.BudgetFriendlyActivity, german_city_tourism_populated.Sight, german_city_tourism_populated.RainyDayOption} => {german_city_tourism_populated.BudgetFriendlyActivity, german_city_tourism_populated.RainyDayOption, german_city_tourism_populated.OpenOnWeekend, german_city_tourism_populated.Sight, german_city_tourism_populated.BadWeatherOption}
# * Owlready * Reparenting german_city_tourism_populated.venue_stammbar_607: {german_city_tourism_populated.BudgetFriendlyActivity, german_city_tourism_populated.NightlifeVenue, german_city_tourism_populated.RainyDayOption} => {german_city_tourism_populated.BudgetFriendlyActivity, german_city_tourism_populated.RainyDayOption, german_city_tourism_populated.NightlifeVenue, german_city_tourism_populated.BadWeatherOption}
# * Owlready * Reparenting german_city_tourism_populated.venue_deutsches_museum_verkehrszentrum_545: {german_city_tourism_populated.BudgetFriendlyActivity, german_city_tourism_populated.Museum, german_city_tourism_populated.RainyDayOption} => {german_city_tourism_populated.BudgetFriendlyActivity, german_city_tourism_populated.RainyDayOption, german_city_tourism_populated.Museum, german_city_tourism_populated.BadWeatherOption, german_city_tourism_populated.OpenOnWeekend}
# * Owlready * Reparenting german_city_tourism_populated.venue_bollwerk_cologne_406: {german_city_tourism_populated.NightlifeVenue, german_city_tourism_populated.RainyDayOption} => {german_city_tourism_populated.RainyDayOption, german_city_tourism_populated.NightlifeVenue, german_city_tourism_populated.BadWeatherOption, german_city_tourism_populated.OpenOnWeekend}
# * Owlready * Reparenting german_city_tourism_populated.venue_kölschbar_375: {german_city_tourism_populated.BudgetFriendlyActivity, german_city_tourism_populated.NightlifeVenue, german_city_tourism_populated.RainyDayOption} => {german_city_tourism_populated.BudgetFriendlyActivity, german_city_tourism_populated.RainyDayOption, german_city_tourism_populated.NightlifeVenue, german_city_tourism_populated.BadWeatherOption, german_city_tourism_populated.OpenOnWeekend}
# * Owlready * Reparenting german_city_tourism_populated.venue_exogallery_1251: {german_city_tourism_populated.BudgetFriendlyActivity, german_city_tourism_populated.Museum, german_city_tourism_populated.RainyDayOption} => {german_city_tourism_populated.BudgetFriendlyActivity, german_city_tourism_populated.RainyDayOption, german_city_tourism_populated.Museum, german_city_tourism_populated.BadWeatherOption, german_city_tourism_populated.OpenOnWeekend}
# * Owlready * Reparenting german_city_tourism_populated.venue_denkstätte_weiße_rose_498: {german_city_tourism_populated.BudgetFriendlyActivity, german_city_tourism_populated.Sight, german_city_tourism_populated.RainyDayOption} => {german_city_tourism_populated.BudgetFriendlyActivity, german_city_tourism_populated.RainyDayOption, german_city_tourism_populated.OpenOnWeekend, german_city_tourism_populated.Sight, german_city_tourism_populated.BadWeatherOption}
# * Owlready * Reparenting german_city_tourism_populated.venue_ev_matthäuskirche_1210: {german_city_tourism_populated.BudgetFriendlyActivity, german_city_tourism_populated.Sight, german_city_tourism_populated.RainyDayOption} => {german_city_tourism_populated.BudgetFriendlyActivity, german_city_tourism_populated.RainyDayOption, german_city_tourism_populated.Sight, german_city_tourism_populated.BadWeatherOption}
# * Owlready * Reparenting german_city_tourism_populated.venue_rheinpark_419: {german_city_tourism_populated.BudgetFriendlyActivity, german_city_tourism_populated.Park, german_city_tourism_populated.FamilyFriendlyActivity} => {german_city_tourism_populated.BudgetFriendlyActivity, german_city_tourism_populated.FamilyFriendlyActivity, german_city_tourism_populated.Park, german_city_tourism_populated.OpenOnWeekend}
# * Owlready * Reparenting german_city_tourism_populated.venue_asamkirche_475: {german_city_tourism_populated.BudgetFriendlyActivity, german_city_tourism_populated.Sight, german_city_tourism_populated.RainyDayOption} => {german_city_tourism_populated.BudgetFriendlyActivity, german_city_tourism_populated.RainyDayOption, german_city_tourism_populated.OpenOnWeekend, german_city_tourism_populated.Sight, german_city_tourism_populated.BadWeatherOption}
# * Owlready * Reparenting german_city_tourism_populated.venue_galerie_33_die_rahmenmacher_1848: {german_city_tourism_populated.BudgetFriendlyActivity, german_city_tourism_populated.Museum, german_city_tourism_populated.RainyDayOption} => {german_city_tourism_populated.BudgetFriendlyActivity, german_city_tourism_populated.RainyDayOption, german_city_tourism_populated.Museum, german_city_tourism_populated.BadWeatherOption}
# * Owlready * Reparenting german_city_tourism_populated.venue_german_resistance_memorial_center_88: {german_city_tourism_populated.BudgetFriendlyActivity, german_city_tourism_populated.Museum, german_city_tourism_populated.RainyDayOption} => {german_city_tourism_populated.BudgetFriendlyActivity, german_city_tourism_populated.RainyDayOption, german_city_tourism_populated.Museum, german_city_tourism_populated.BadWeatherOption, german_city_tourism_populated.OpenOnWeekend}
# * Owlready * Reparenting german_city_tourism_populated.venue_wildpark_426: {german_city_tourism_populated.BudgetFriendlyActivity, german_city_tourism_populated.Park, german_city_tourism_populated.FamilyFriendlyActivity} => {german_city_tourism_populated.BudgetFriendlyActivity, german_city_tourism_populated.FamilyFriendlyActivity, german_city_tourism_populated.Park, german_city_tourism_populated.OpenOnWeekend}
# * Owlready * Reparenting german_city_tourism_populated.venue_tempodrom_53: {german_city_tourism_populated.Sight, german_city_tourism_populated.RainyDayOption} => {german_city_tourism_populated.RainyDayOption, german_city_tourism_populated.Sight, german_city_tourism_populated.BadWeatherOption}
# * Owlready * Reparenting german_city_tourism_populated.venue_mahnmal_st_nikolai_773: {german_city_tourism_populated.BudgetFriendlyActivity, german_city_tourism_populated.Museum, german_city_tourism_populated.RainyDayOption} => {german_city_tourism_populated.BudgetFriendlyActivity, german_city_tourism_populated.RainyDayOption, german_city_tourism_populated.Museum, german_city_tourism_populated.BadWeatherOption, german_city_tourism_populated.OpenOnWeekend}
# * Owlready * Reparenting german_city_tourism_populated.venue_ikonenmuseum_1062: {german_city_tourism_populated.BudgetFriendlyActivity, german_city_tourism_populated.Museum, german_city_tourism_populated.RainyDayOption} => {german_city_tourism_populated.BudgetFriendlyActivity, german_city_tourism_populated.RainyDayOption, german_city_tourism_populated.Museum, german_city_tourism_populated.BadWeatherOption, german_city_tourism_populated.OpenOnWeekend}
# * Owlready * Reparenting german_city_tourism_populated.venue_german_sports_and_olympic_museum_302: {german_city_tourism_populated.BudgetFriendlyActivity, german_city_tourism_populated.Museum, german_city_tourism_populated.RainyDayOption} => {german_city_tourism_populated.BudgetFriendlyActivity, german_city_tourism_populated.RainyDayOption, german_city_tourism_populated.Museum, german_city_tourism_populated.BadWeatherOption, german_city_tourism_populated.OpenOnWeekend}
# * Owlready * Reparenting german_city_tourism_populated.venue_lunacy_hamburg_st_pauli_862: {german_city_tourism_populated.BudgetFriendlyActivity, german_city_tourism_populated.NightlifeVenue, german_city_tourism_populated.RainyDayOption} => {german_city_tourism_populated.BudgetFriendlyActivity, german_city_tourism_populated.RainyDayOption, german_city_tourism_populated.NightlifeVenue, german_city_tourism_populated.BadWeatherOption, german_city_tourism_populated.OpenOnWeekend}
# * Owlready * Reparenting german_city_tourism_populated.venue_oktorail_1829: {german_city_tourism_populated.BudgetFriendlyActivity, german_city_tourism_populated.Museum, german_city_tourism_populated.RainyDayOption} => {german_city_tourism_populated.BudgetFriendlyActivity, german_city_tourism_populated.RainyDayOption, german_city_tourism_populated.Museum, german_city_tourism_populated.BadWeatherOption}
# * Owlready * Reparenting german_city_tourism_populated.tour_munich_bmw_museum_bmw_welt_private_guided_tour_356: {german_city_tourism_populated.EnglishFriendlyTour, german_city_tourism_populated.RainyDayOption} => {german_city_tourism_populated.EnglishFriendlyTour, german_city_tourism_populated.RainyDayOption, german_city_tourism_populated.BadWeatherOption}
# * Owlready * (NB: only changes on entities loaded in Python are shown, other changes are done but not listed)

# %%
# Save the ontology with the new rules
onto.save(file=str(OUTPUT_PATH), format="rdfxml")
print(f"Ontology with SWRL rules saved to: {OUTPUT_PATH}")
# Out:
# Ontology with SWRL rules saved to: /Users/conocirone/Desktop/german_travel_companion/ontologies/populated/german_city_tourism_with_rules.owl

# %% [markdown]
# ## Summary of SWRL Rules
#
# | # | Rule Name | SWRL Syntax | Purpose |
# |---|-----------|-------------|----------|
# | 1a | BudgetFriendlyActivity (Free) | `Activity(?a), hasBudget(?a, budget_free) -> BudgetFriendlyActivity(?a)` | Classify free activities |
# | 1b | BudgetFriendlyActivity (Low) | `Activity(?a), hasBudget(?a, budget_low) -> BudgetFriendlyActivity(?a)` | Classify low-cost activities |
# | 2 | BadWeatherOption | `Activity(?a), hasLocationSetting(?a, location_indoor) -> BadWeatherOption(?a)` | Weather-based recommendations |
# | 3 | EnglishFriendlyTour | `Tour(?t), hasLanguage(?t, lang_english) -> EnglishFriendlyTour(?t)` | International tourist accessibility |
# | 4a | WeekendHours (Saturday) | `OperatingHours(?oh), appliesToDay(?oh, day_saturday) -> WeekendHours(?oh)` | Identify Saturday hours |
# | 4b | WeekendHours (Sunday) | `OperatingHours(?oh), appliesToDay(?oh, day_sunday) -> WeekendHours(?oh)` | Identify Sunday hours |
# | 5 | OpenOnWeekend | `PhysicalVenue(?v), hasOperatingHours(?v, ?oh), WeekendHours(?oh) -> OpenOnWeekend(?v)` | Find weekend venues |
#
#
# ### Use Cases
#
# - **Budget Planning**: Query `BudgetFriendlyActivity` to find affordable options
# - **Weather Adaptation**: Query `BadWeatherOption` when weather is bad
# - **Tourist Accessibility**: Query `EnglishFriendlyTour` for non-German speakers
# - **Weekend Planning**: Query `OpenOnWeekend` to find venues open on weekends
